# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, roc_curve, auc
#Load dataset using Pandas
data=pd.read_csv('winequality-red.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#Convert PySpark dataset to Pandas
data=df.toPandas()
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Convert PySpark dataset to Pandas
# ----> 2 data=df.toPandas()
#       3 data.head()
#
# NameError: name 'df' is not defined

# %%
# Remove rows with missing values
data.dropna(inplace=True)

# %%
# Check for null values again after cleanup
print("Null values after cleanup:")
print(data.isnull().sum())
# Out:
# Null values after cleanup:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#show number of rolls and detail of dataframe
data.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Compute the correlation matrix - Developer PMA
# Calculate correlation matrix
correlation_matrix = data.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Draw the heatmap with the mask and correct aspect ratio
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Add title
plt.title('Correlation Matrix Heatmap - Red Wine Quality')

# Highlight correlations with 'Potability'
highlight = correlation_matrix['quality'].sort_values(ascending=False)
highlight = highlight.drop('quality')  # Remove self-correlation
highlight_cols = highlight.index.tolist()
heatmap.add_patch(plt.Rectangle((0, 0), len(correlation_matrix), len(highlight_cols), fill=False, edgecolor='blue', lw=3))

# Show plot
plt.show()

# %%
quality_counts = data['quality'].value_counts()

# Sort the value counts Series by index in descending order
quality_counts_sorted = quality_counts.sort_index(ascending=False)

quality_df = pd.DataFrame(quality_counts_sorted)
quality_df
# Out:
#          count
# quality
# 8           18
# 7          199
# 6          638
# 5          681
# 4           53
# 3           10

# %%
# Separate features and target variable
X = data.drop('quality', axis=1)
y = data['quality']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
# Normalize or scale the features if necessary
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Initialize and fit the Random Forest model
rf_model = RandomForestClassifier(random_state=50)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=50)

# %%
# Make predictions on the test set
y_pred = rf_model.predict(X_test)

# Get feature importances
feature_importances = rf_model.feature_importances_

# Create a DataFrame to display feature importances
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Display feature importances
print("Feature Importance (Random Forest):")
print(importance_df)
# Out:
# Feature Importance (Random Forest):
#                  Feature  Importance
# 10               alcohol    0.150342
# 9              sulphates    0.108571
# 1       volatile acidity    0.103699
# 6   total sulfur dioxide    0.102103
# 7                density    0.093315
# 4              chlorides    0.081399
# 0          fixed acidity    0.079157
# 8                     pH    0.074902
# 2            citric acid    0.074011
# 3         residual sugar    0.068778
# 5    free sulfur dioxide    0.063722

# %%
# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.title('Feature Importance (Random Forest)')
plt.gca().invert_yaxis()  # Invert y-axis to display features with the most important at the top
plt.show()

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.740625

# %% [markdown]
# # Optimisation - Defining a threshold of wine quality

# %%
X = data.drop(['quality'], axis=1)
y = data['quality']

# %%
# Convert quality into categories (assuming good: 6.10, bad: =5 and below)
threshold = 6
y_binary = (y >= threshold).astype(int)  # 1 for good, 0 for bad

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_binary, test_size=0.2, random_state=42)

# Feature scaling (standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

# Make predictions on test set
y_pred = model.predict(X_test_scaled)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy score
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.7500

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
#Plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Analysis
# An ROC curve area of 0.75 indicates the overall performance of the logistic regression model in distinguishing between the positive class and the negative class. Here's what an AUC of 0.75 implies:
#
# Interpretation: AUC values range from 0 to 1, where higher values indicate better performance. An AUC of 0.75 suggests that the model has a 75% chance of correctly ranking a randomly chosen positive instance higher than a randomly chosen negative instance.
#
# Discrimination Power: An AUC of 0.75 indicates that the model has moderate discrimination power in separating the positive and negative classes. It performs better than a random classifier (AUC = 0.5) but may not achieve perfect separation.

# %%
# Calculate precision and recall
precision, recall, _ = precision_recall_curve(y_test, y_pred)

# Calculate average precision score
average_precision = average_precision_score(y_test, y_pred)

# Plot Precision-Recall curve
plt.figure()
plt.step(recall, precision, color='b', alpha=0.2, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Curve (Average Precision = {0:0.2f})'.format(average_precision))
plt.show()

# %% [markdown]
# # Analysis
# Model present a moderate accuracy of 75% , but when comparing the precision on calling good from bad, by the precision score we are calling with confidence a good wine only 74% of the time.
#
# #Higher is Better: Average precision scores range from 0 to 1, where higher values indicate better performance. An average precision of 0.74 indicates a relatively balanced trade-off between precision and recall.
#
# #Interpretation: An average precision score of 0.37 means that, on average, the model achieves a precision of 0.37 across different recall levels. In other words, when the model predicts a wine quality as "good," it is correct about 37% of the time.

# %%
# Calculate the F1 score
f1 = f1_score(y_test, y_pred)

# Print the F1 score
print("F1 Score:", f1)

# Plot the F1 score
plt.figure()
plt.bar(["F1 Score"], [f1], color='blue')
plt.xlabel('Metric')
plt.ylabel('Score')
plt.title('F1 Score')
plt.ylim(0, 1)
plt.show()
# Out:
# F1 Score: 0.7660818713450293

# %% [markdown]
# # Optimisation - Decision Tree

# %%
X = data.drop(['free sulfur dioxide','quality'], axis=1)
y = data['quality']

# Convert quality into categories (assuming good: 7.10, bad: =6 and below)
threshold = 7
y_binary = (y >= threshold).astype(int)  # 1 for good, 0 for bad

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_binary, test_size=0.2, random_state=42)

# Initialize Decision Tree classifier
model = DecisionTreeClassifier(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Make predictions on test set
y_pred = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy score
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8719

# %% [markdown]
# # Optimisation - Dimension Deduction Leena

# %% [markdown]
# # PCA & Explained Variance Ratio by Principal Component

# %%
# Initialize StandardScaler and fit-transform the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize PCA and fit-transform the scaled features
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Get explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Create a DataFrame to display explained variance ratio
pca_df = pd.DataFrame({'PC': range(1, len(explained_variance_ratio)+1), 'Explained Variance Ratio': explained_variance_ratio})

# Display explained variance ratio
print("\nExplained Variance Ratio (PCA):")
print(pca_df)
# Out:
# Explained Variance Ratio (PCA):
#    PC  Explained Variance Ratio
# 0   1                  0.309674
# 1   2                  0.173702
# 2   3                  0.122114
# 3   4                  0.113654
# 4   5                  0.089724
# 5   6                  0.065945
# 6   7                  0.057591
# 7   8                  0.041535
# 8   9                  0.019993
# 9  10                  0.006067

# %%
# Plot explained variance ratio
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance_ratio)+1), explained_variance_ratio, marker='o', linestyle='--')
plt.title('Explained Variance Ratio by Principal Component')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.xticks(range(1, len(explained_variance_ratio)+1))
plt.grid(True)
plt.show()

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.753125

# %% [markdown]
# # Outcome
#
# Cost Reduction: Using fewer quality parameters in the predictive model may reduce the cost associated with data collection and analysis. Wineries may no longer need to collect extensive data on every aspect of wine production, leading to cost savings.
#
# Efficiency Improvement: Simplifying the predictive model can streamline the quality assessment process, making it more efficient and less labor-intensive. Winemakers can focus on the most critical quality parameters, allowing them to make quicker decisions during production.
#
# Accessibility: A predictive model based on fewer quality parameters may be more accessible to smaller wineries with limited resources. It lowers the barrier to entry for implementing quality control measures and improving wine production processes.
#
# Quality Control: Despite using fewer parameters, a well-constructed predictive model can still provide valuable insights into wine quality. Wineries can use the model to identify potential issues early in the production process and take corrective actions to maintain or improve wine quality.
#
# Consistency: By focusing on a smaller set of quality parameters, wineries can strive for greater consistency in their wine production. Predictive models can help ensure that each batch of wine meets the desired quality standards, leading to more consistent products and customer satisfaction.
#
# Innovation: Simplifying the quality assessment process can free up resources for experimentation and innovation. Wineries may have more time and resources to explore new winemaking techniques, grape varieties, and flavor profiles, leading to product differentiation and market competitiveness.
#
# Market Positioning: A predictive model of wine quality based on fewer parameters can help wineries differentiate themselves in the market. They can highlight their commitment to quality while emphasizing the unique characteristics of their wines, appealing to consumers who value simplicity and authenticity.
